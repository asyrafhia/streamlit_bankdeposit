# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
BASE_PATH = 'gdrive/My Drive/Binus S2 MTI/3. Machine Learning/Assignment & AoL/'
# BASE_PATH = './'
DATA_PATH = BASE_PATH + 'data/'
MODEL_PATH = BASE_PATH + 'models/'

# %%
from oauth2client.service_account import ServiceAccountCredentials
import gspread as gs
from gspread_dataframe import set_with_dataframe

import pandas as pd

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(MODEL_PATH + 'service-account.json', scope)
gc = gs.authorize(credentials)

# %%
spreadsheet = gc.open('bank-full')
worksheet = spreadsheet.worksheet('bank-full')
existing_data = worksheet.get_all_values()
df_train = pd.DataFrame(existing_data[1:], columns=existing_data[0])

int_cols = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
# df_train[int_cols] = df_train[int_cols].astype('int')

print(df_train[int_cols].dtypes)
df_train
# Out:
# age         object
# balance     object
# day         object
# duration    object
# campaign    object
# pdays       object
# previous    object
# dtype: object
#       age           job   marital  education default balance housing loan  \
# 0      58    management   married   tertiary      no   2,143     yes   no
# 1      44    technician    single  secondary      no      29     yes   no
# 2      33  entrepreneur   married  secondary      no       2     yes  yes
# 3      47   blue-collar   married    unknown      no   1,506     yes   no
# 4      33       unknown    single    unknown      no       1      no   no
# ...    ..           ...       ...        ...     ...     ...     ...  ...
# 45206  51    technician   married   tertiary      no     825      no   no
# 45207  71       retired  divorced    primary      no   1,729      no   no
# 45208  72       retired   married  secondary      no   5,715      no   no
# ...
